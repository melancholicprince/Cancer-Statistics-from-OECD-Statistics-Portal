# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("OECD_HEALTH_STAT_CANCER_STATISTICS.csv")
data
# Out:
#            VAR                       Variable      UNIT  \
# 0     CANCTOCA            Malignant neoplasms  PERCMTTX
# 1     CANCTOCA            Malignant neoplasms  PERCMTTX
# 2     CANCTOCA            Malignant neoplasms  PERCMTTX
# 3     CANCCOLC   Malignant neoplasms of colon  PERCMTTX
# 4     CANCCOLC   Malignant neoplasms of colon  PERCMTTX
# ...        ...                            ...       ...
# 2971  CANCCOLC   Malignant neoplasms of colon  NBPOPIPC
# 2972  CANCLUNC    Malignant neoplasms of lung  PERCMTTX
# 2973  CANCCOLC   Malignant neoplasms of colon  INCITFTF
# 2974  CANCCEIX  Malignant neoplasms of cervix  NBWOMAPF
# 2975  CANCLUNC    Malignant neoplasms of lung  INCITHTH
#
#                                Measure  COU     Country   YEA  Year   Value  \
# 0     Incidence per 100 000 population  AUS   Australia  2002  2002   312.0
# 1     Incidence per 100 000 population  AUS   Australia  2008  2008   314.1
# 2     Incidence per 100 000 population  AUS   Australia  2012  2012   323.0
# 3     Incidence per 100 000 population  AUS   Australia  2002  2002    41.7
# 4     Incidence per 100 000 population  AUS   Australia  2008  2008    38.7
# ...                                ...  ...         ...   ...   ...     ...
# 2971             Number of total cases  COL    Colombia  2012  2012  5663.0
# 2972  Incidence per 100 000 population  LTU   Lithuania  2012  2012    26.2
# 2973     Incidence per 100 000 females  LTU   Lithuania  2012  2012    18.9
# 2974            Number of female cases  LTU   Lithuania  2012  2012   615.0
# 2975       Incidence per 100 000 males  CRI  Costa Rica  2012  2012     9.8
#
#       Flag Codes  Flags
# 0            NaN    NaN
# 1            NaN    NaN
# 2            NaN    NaN
# 3            NaN    NaN
# 4            NaN    NaN
# ...          ...    ...
# 2971         NaN    NaN
# 2972         NaN    NaN
# 2973         NaN    NaN
# 2974         NaN    NaN
# 2975         NaN    NaN
#
# [2976 rows x 11 columns]

# %%
data1 = data.head(10)
data1
data2 = data.head(15)
data1
# Out:
#         VAR                      Variable      UNIT  \
# 0  CANCTOCA           Malignant neoplasms  PERCMTTX
# 1  CANCTOCA           Malignant neoplasms  PERCMTTX
# 2  CANCTOCA           Malignant neoplasms  PERCMTTX
# 3  CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 4  CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 5  CANCCOLC  Malignant neoplasms of colon  PERCMTTX
# 6  CANCLUNC   Malignant neoplasms of lung  PERCMTTX
# 7  CANCLUNC   Malignant neoplasms of lung  PERCMTTX
# 8  CANCLUNC   Malignant neoplasms of lung  PERCMTTX
# 9  CANCTOCA           Malignant neoplasms  PERCMTTX
#
#                             Measure  COU    Country   YEA  Year  Value  \
# 0  Incidence per 100 000 population  AUS  Australia  2002  2002  312.0
# 1  Incidence per 100 000 population  AUS  Australia  2008  2008  314.1
# 2  Incidence per 100 000 population  AUS  Australia  2012  2012  323.0
# 3  Incidence per 100 000 population  AUS  Australia  2002  2002   41.7
# 4  Incidence per 100 000 population  AUS  Australia  2008  2008   38.7
# 5  Incidence per 100 000 population  AUS  Australia  2012  2012   38.4
# 6  Incidence per 100 000 population  AUS  Australia  2002  2002   28.2
# 7  Incidence per 100 000 population  AUS  Australia  2008  2008   25.6
# 8  Incidence per 100 000 population  AUS  Australia  2012  2012   27.0
# 9  Incidence per 100 000 population  AUT    Austria  2000  2000  250.7
#
#    Flag Codes  Flags
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN
# 5         NaN    NaN
# 6         NaN    NaN
# 7         NaN    NaN
# 8         NaN    NaN
# 9         NaN    NaN

# %%
#Three lines to make our compiler able to draw:
import sys
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("OECD_HEALTH_STAT_CANCER_STATISTICS.csv")

df.plot(kind = 'scatter', x = 'Year', y = 'Value')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
